# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("cat_picture.jpg")

# %%
if img is None: # If file doesn't exist
    print("Image {} hasn't been loaded".format(img))
else:
    print("Image has been loaded successfully")
# Out:
# Image has been loaded successfully

# %%
img.shape
# Out:
# (390, 624, 3)

# %%
plt.imshow(img)

# %%
# Matplitlib - Red Green Blue 
# OpenCV - Blue - Green - Red
fixed_img = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2RGB)
plt.imshow(fixed_img)

# %%
img_gray = cv2.imread("cat_picture.jpg", cv2.IMREAD_GRAYSCALE)
if img is None: # If file doesn't exist
    print("Image {} hasn't been loaded".format(img))
else:
    print("Image has been loaded successfully")
    plt.imshow(img_gray, cmap="gray")
# Out:
# Image has been loaded successfully

# %%
img_gray.shape # No need for more channel
# Out:
# (390, 624)

# %%
img_gray.min() # The lightest color
# Out:
# 6

# %%
img_gray.max() # The darkest color - Range from 0 - 255
# Out:
# 255

# %%
fixed_img.shape # height, width, color_channels
# Out:
# (390, 624, 3)

# %%
new_img = cv2.resize(fixed_img, (200, 300))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fixed_img, (0,0), fixed_img, w_ratio, h_ratio)
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (195, 312, 3)

# %%
new_img = cv2.flip(fixed_img, 0)
plt.imshow(new_img)

# %%
new_img = cv2.flip(fixed_img, 1)
plt.imshow(new_img)

# %%
new_img = cv2.flip(fixed_img, -1)
plt.imshow(new_img)

# %%
plt.imshow(fixed_img)
