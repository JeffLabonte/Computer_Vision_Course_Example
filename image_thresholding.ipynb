# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
img = cv2.imread('DATA/rainbow.jpg', 0)

# %%
plt.imshow(img, cmap='gray')

# %%
ret, thresh_one = cv2.threshold(src=img, thresh=127, maxval=255, type=cv2. THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh_one, cmap='gray')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-16-7fde150692a2> in <module>()
# ----> 1 plt.imshow(thresh_one, cmp='gray')
#
# /usr/lib64/python2.7/site-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3208                         filternorm=filternorm, filterrad=filterrad,
#    3209                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3210                         **kwargs)
#    3211     finally:
#    3212         ax._hold = washold
#
# /usr/lib64/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
# ...
